# %% [markdown]
# <a href="https://colab.research.google.com/github/kimve1969/mgu_ds_cours/blob/main/semestr%202.1/task%203/semestr_2_1_task_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ВМК МГУ, Курс по Data Science (DS) и Machine Learning (ML) 2026 год
# 2 семестр, Анализ данных в Python,
# Ким Виталий Евгеньевич, ПАО "Сургутнефтегаз"
# 22.07.2026

# %% [markdown]
# ## Задание 3. Разведочный анализ

# %%
import pandas as pd
# подготавливаем файлы
# !wget -N https://raw.githubusercontent.com/kimve1969/mgu_ds_cours/refs/heads/main/semestr%202.1/task%203/surveys.csv
# !wget -N https://raw.githubusercontent.com/kimve1969/mgu_ds_cours/refs/heads/main/semestr%202.1/task%203/species.csv
# !wget -N https://raw.githubusercontent.com/kimve1969/mgu_ds_cours/refs/heads/main/semestr%202.1/task%203/plot_location.xlsx
# Out:
# --2026-07-27 17:19:47--  https://raw.githubusercontent.com/kimve1969/mgu_ds_cours/refs/heads/main/semestr%202.1/task%203/surveys.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1478951 (1.4M) [text/plain]
# Saving to: ‘surveys.csv’
#
# surveys.csv         100%[===================>]   1.41M  --.-KB/s    in 0.01s
#
# Last-modified header missing -- time-stamps turned off.
# 2026-07-27 17:19:47 (145 MB/s) - ‘surveys.csv’ saved [1478951/1478951]
#
# --2026-07-27 17:19:47--  https://raw.githubusercontent.com/kimve1969/mgu_ds_cours/refs/heads/main/semestr%202.1/task%203/species.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# ...

# %% [markdown]
# # 1. Данные опроса

# %%
# считываем данные опроса
surveys_data = pd.read_csv('surveys.csv')
surveys_data
# Out:
#        record_id  month  day  year  plot species sex_char   wgt
# 0              1      7   16  1977     2     NaN        M   NaN
# 1              2      7   16  1977     3     NaN        M   NaN
# 2              3      7   16  1977     2      DM        F   NaN
# 3              4      7   16  1977     7      DM        M   NaN
# 4              5      7   16  1977     3      DM        M   NaN
# ...          ...    ...  ...   ...   ...     ...      ...   ...
# 35544      35545     12   31  2002    15      AH      NaN   NaN
# 35545      35546     12   31  2002    15      AH      NaN   NaN
# 35546      35547     12   31  2002    10      RM        F  14.0
# 35547      35548     12   31  2002     7      DO        M  51.0
# 35548      35549     12   31  2002     5     NaN      NaN   NaN
#
# [35549 rows x 8 columns]

# %%
# дублирующих записей нет sum()==0
surveys_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
surveys_data['datasetname'] = 'Ecological Archives E090-118-D1'
surveys_data
# Out:
#        record_id  month  day  year  plot species sex_char   wgt  \
# 0              1      7   16  1977     2     NaN        M   NaN
# 1              2      7   16  1977     3     NaN        M   NaN
# 2              3      7   16  1977     2      DM        F   NaN
# 3              4      7   16  1977     7      DM        M   NaN
# 4              5      7   16  1977     3      DM        M   NaN
# ...          ...    ...  ...   ...   ...     ...      ...   ...
# 35544      35545     12   31  2002    15      AH      NaN   NaN
# 35545      35546     12   31  2002    15      AH      NaN   NaN
# 35546      35547     12   31  2002    10      RM        F  14.0
# 35547      35548     12   31  2002     7      DO        M  51.0
# 35548      35549     12   31  2002     5     NaN      NaN   NaN
#
#                            datasetname
# 0      Ecological Archives E090-118-D1
# 1      Ecological Archives E090-118-D1
# 2      Ecological Archives E090-118-D1
# ...

# %%
surveys_data.groupby(by='sex_char').count()
# Out:
#           record_id  month    day   year   plot  species    wgt  datasetname
# sex_char
# F             15689  15689  15689  15689  15689    15014  15303        15689
# M             17348  17348  17348  17348  17348    16846  16879        17348
# P                 1      1      1      1      1        1      1            1
# R                 3      3      3      3      3        3      0            3
# Z                 1      1      1      1      1        1      1            1

# %%
from typing_extensions import TypeVarTuple
# сохраняем исходную информацию о поле
surveys_data.rename(columns={'sex_char':'verbatimSex'}, inplace=True)
# Out:
#        record_id  month  day  year  plot species verbatimSex   wgt  \
# 0              1      7   16  1977     2     NaN           M   NaN
# 1              2      7   16  1977     3     NaN           M   NaN
# 2              3      7   16  1977     2      DM           F   NaN
# 3              4      7   16  1977     7      DM           M   NaN
# 4              5      7   16  1977     3      DM           M   NaN
# ...          ...    ...  ...   ...   ...     ...         ...   ...
# 35544      35545     12   31  2002    15      AH         NaN   NaN
# 35545      35546     12   31  2002    15      AH         NaN   NaN
# 35546      35547     12   31  2002    10      RM           F  14.0
# 35547      35548     12   31  2002     7      DO           M  51.0
# 35548      35549     12   31  2002     5     NaN         NaN   NaN
#
#                            datasetname
# 0      Ecological Archives E090-118-D1
# 1      Ecological Archives E090-118-D1
# 2      Ecological Archives E090-118-D1
# ...

# %%
surveys_data[ surveys_data['verbatimSex'] == 'P']['sex'] = 'M'
# Out:
# /tmp/ipykernel_828/3204832035.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   surveys_data[ surveys_data['verbatimSex'] == 'P']['sex'] = 'M'

# %%
species_data = pd.read_csv('species.csv', sep=';')
species_data
# Out:
#    species_id             genus          species                   taxa
# 0          AB        Amphispiza        bilineata                   Bird
# 1          AH  Ammospermophilus          harrisi    Rodent-not censused
# 2          AS        Ammodramus       savannarum                   Bird
# 3          BA           Baiomys          taylori                 Rodent
# 4          CB   Campylorhynchus  brunneicapillus                   Bird
# 5          CM       Calamospiza      melanocorys                   Bird
# 6          CQ        Callipepla         squamata                   Bird
# 7          CS          Crotalus       scutalatus                Reptile
# 8          CT     Cnemidophorus           tigris                Reptile
# 9          CU     Cnemidophorus        uniparens                Reptile
# 10         CV          Crotalus          viridis                Reptile
# 11         DM         Dipodomys         merriami                 Rodent
# ...

# %%
plot_data = pd.read_excel('plot_location.xlsx')
plot_data
# Out:
#           Coordinates Ecological Archives E090-118-D1 Unnamed: 1  \
# 0   http://esapubs.org/archive/ecol/E090/118/Porta...        NaN
# 1                                                 NaN        NaN
# 2                                                 NaN       plot
# 3                                                   0          1
# 4                                                   1          2
# 5                                                   2          3
# 6                                                   3          4
# 7                                                   4          5
# 8                                                   5          6
# 9                                                   6          7
# 10                                                  7          8
# 11                                                  8          9
# 12                                                  9         10
# ...
